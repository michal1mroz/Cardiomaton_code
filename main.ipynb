# %%
from utils.data_reader import *
from models.automaton import Automaton
from models.cell_state import CellState

import matplotlib.pyplot as plt

# %%
graph = load_to_binary_array("resources/CCS.png", 1500)
plt.imshow(graph, cmap='gray')
plt.show()

# %%
graph = np.ones((10, 10))
auto = Automaton(graph, 0.2)
auto.automaton[4,4].self_polarization = True
auto.automaton[4,4].state = CellState.POLARIZATION

auto.run_simulation()

# %%
graph = load_to_binary_array("resources/CCS.png", 1500)
plt.imshow(graph, cmap='gray')
plt.show()

# %%
auto = Automaton(graph)
auto.automaton[50, 22].self_polarization = True
auto.automaton[50,22].state = CellState.POLARIZATION
auto.run_simulation()
